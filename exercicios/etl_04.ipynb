# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/alanjones2/dataviz/raw/master/londonweather.csv')

# %%
# verificando quantidade de duplicatas

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# obtendo dados de temperaturas

temp_1957 = df[df['Year'] == 1957].Tmax
temp_1977 = df[df['Year'] == 1977].Tmax
temp_1997 = df[df['Year'] == 1997].Tmax
temp_2017 = df[df['Year'] == 2017].Tmax
temp_2017
# Out:
# 720     7.6
# 721    10.0
# 722    14.1
# 723    15.8
# 724    19.8
# 725    24.0
# 726    23.8
# 727    22.0
# 728    19.2
# 729    17.1
# 730    11.1
# 731     8.7
# Name: Tmax, dtype: float64

# %%
import pandas as pd

import matplotlib.pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/alanjones2/dataviz/master/londonweather.csv")

df_1957 = df[(df.Year == 1957)]

plt.plot(df_1957['Month'], df_1957['Tmax']);
